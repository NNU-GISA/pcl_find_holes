# %%
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from pandas import DataFrame

# %%
data = pd.read_csv('20160426_CALIB.txt', sep=" ", header=None);

# %%
data.shape
data.groupby(lambda x: x/2).mean().shape
# Out:
# (285552, 3)

# %%
print(data.index)
# Out:
# RangeIndex(start=0, stop=285552, step=1)

# %%
threedee = plt.figure().gca(projection='3d')
threedee.scatter(data[0], data[1], data[2])
